# %%
# %run "./Cleanse by Data Type/String"

# %%
class Clean:
  
  cleanseString=CleanseString()
  def cln_title_case(self, df, df_errors, columns: list, error_action: str, error_replace_value=None): 
    df_cleaned, df_errors = self.cleanseString.cln_title_case(df=df, df_errors=df_errors, columns=columns, error_action=error_action, error_replace_value=error_replace_value)
    return df_cleaned, df_errors  
  
  def cln_lower_case(self, df, df_errors, columns: list, error_action: str, error_replace_value=None): 
    df_cleaned, df_errors = self.cleanseString.cln_lower_case(df=df, df_errors=df_errors, columns=columns, error_action=error_action, error_replace_value=error_replace_value)
    return df_cleaned, df_errors
  
  def cln_upper_case(self, df, df_errors, columns: list, error_action: str, error_replace_value=None): 
    df_cleaned, df_errors = self.cleanseString.cln_upper_case(df=df, df_errors=df_errors, columns=columns, error_action=error_action, error_replace_value=error_replace_value)
    return df_cleaned, df_errors
  
  def cln_regex_replace(self, df, df_errors, columns: list, regex_exp: str, replace_string: str, error_action: str, error_replace_value=None): 
    df_cleaned, df_errors = self.cleanseString.cln_regex_replace(df=df, df_errors=df_errors, columns=columns, regex_exp=regex_exp, replace_string=replace_string, error_action=error_action, error_replace_value=error_replace_value)
    return df_cleaned, df_errors
  
  def cln_fuzzy_match_replace(self, df, df_errors, columns: list, common_strings: list, similarity_threshold: float, error_action: str, error_replace_value=None):
    df_cleaned, df_errors = self.cleanseString.cln_fuzzy_match_replace(df=df, df_errors=df_errors, columns=columns, common_strings=common_strings, similarity_threshold=similarity_threshold, error_action=error_action, error_replace_value=error_replace_value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...
